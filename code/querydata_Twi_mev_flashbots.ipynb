# %% [markdown]
# # Query mev tag data

# %%
# !pip3 install snscrape
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd
import snscrape.modules.twitter

# %%
# Creating list to append tweet data to
tweets_list = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('#MEV since:2008-04-01 until:2022-01-01 min_faves:3 exclude:retweets','corona lang:en').get_items()):
    tweets_list.append([tweet.date,  tweet.content]) #tweet.id
tweets_list
# Out:
# [[datetime.datetime(2021, 12, 31, 5, 49, 28, tzinfo=datetime.timezone.utc),
#   "This is what a sandwich attack looks like. They're common on low cap pairs, and it's when bots scan for buy orders then front run buy/sell orders on either side, causing a trader's buy order to execute at a much higher price than intended, and pocketing the difference. #mev $year https://t.co/oPlmd7s9mw"],
#  [datetime.datetime(2021, 12, 28, 17, 14, 22, tzinfo=datetime.timezone.utc),
#   '¿Sabías que en el mundo de las #DeFi existen estrategias controversiales que sacan provecho de una manera poco sana para el mercado llamadas #MEV?\n\nEntérate como #Assembly puede poner fin a esta manipulación en las DeFi. \n📝🧐\nhttps://t.co/yQWAD7SRqv'],
#  [datetime.datetime(2021, 12, 27, 11, 0, 25, tzinfo=datetime.timezone.utc),
# ...

# %%
result= pd.DataFrame(tweets_list, columns=['Date', 'Tweets'])
result
# Out:
#                          Date  \
# 0   2021-12-31 05:49:28+00:00
# 1   2021-12-28 17:14:22+00:00
# 2   2021-12-27 11:00:25+00:00
# 3   2021-12-27 10:00:34+00:00
# 4   2021-12-27 02:32:05+00:00
# ..                        ...
# 648 2018-04-25 14:27:16+00:00
# 649 2018-04-09 11:00:21+00:00
# 650 2018-04-07 11:35:12+00:00
# 651 2018-03-31 13:15:06+00:00
# 652 2018-03-12 22:24:45+00:00
#
#                                                 Tweets
# 0    This is what a sandwich attack looks like. The...
# 1    ¿Sabías que en el mundo de las #DeFi existen e...
# 2    [#IOTAQuicktakes] Let’s wrap up this year with...
# 3    [#IOTAQuicktakes] Let’s wrap up this year with...
# 4    What is Miner extractable value (#MEV) and how...
# ..                                                 ...
# 648  #CheamVillage - fun morning spent installing @...
# 649  #AirPollution plays a role in many of the majo...
# 650  Viatge d'incognit a #Catalunya #padepassíc #ME...
# ...

# %%
result.to_csv('mev.csv')

# %% [markdown]
# # Query flashbots tag data

# %%
tweets_list2 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('#flashbots since:2021-03-15 until:2022-01-01 min_faves:3 exclude:retweets','corona lang:en').get_items()):
    tweets_list2.append([tweet.date,  tweet.content]) #tweet.id
tweets_list2
# Out:
# [[datetime.datetime(2021, 12, 31, 10, 36, 24, tzinfo=datetime.timezone.utc),
#   'Support new artist, help us grow!! Shill the Shizzlebotz! \n\n #nftshill #PolygonNFT #flashbots https://t.co/5SizQ7JDpe @opensea #openseaNFT⛵'],
#  [datetime.datetime(2021, 12, 27, 18, 37, 50, tzinfo=datetime.timezone.utc),
#   'Support new artist, help us grow!! Shill the Shizzlebotz! \n\n #nftshill #PolygonNFT #flashbots https://t.co/CFIaxgvJbK @opensea #openseaNFT⛵'],
#  [datetime.datetime(2021, 12, 26, 6, 41, 29, tzinfo=datetime.timezone.utc),
#   'Support new artist, help us grow!! Shill the Shizzlebotz! \n\n #nftshill #PolygonNFT #flashbots https://t.co/5SizQ7JDpe @opensea #openseaNFT⛵'],
#  [datetime.datetime(2021, 12, 18, 16, 36, 53, tzinfo=datetime.timezone.utc),
#   'Support new artist, help us grow!! Shill the Shizzlebotz! \n\n #nftshill #PolygonNFT #flashbots https://t.co/5SizQ7JDpe @opensea #openseaNFT⛵'],
#  [datetime.datetime(2021, 12, 13, 15, 11, 25, tzinfo=datetime.timezone.utc),
# ...

# %%
result2= pd.DataFrame(tweets_list2, columns=['Date', 'Tweets'])
result2
result2.to_csv('flashbots.csv')

# %%
see = pd.read_csv('/content/flashbots.csv')
see
# Out:
#      Unnamed: 0                       Date  \
# 0             0  2021-12-31 10:36:24+00:00
# 1             1  2021-12-27 18:37:50+00:00
# 2             2  2021-12-26 06:41:29+00:00
# 3             3  2021-12-18 16:36:53+00:00
# 4             4  2021-12-13 15:11:25+00:00
# ..          ...                        ...
# 221         221  2021-03-19 23:48:43+00:00
# 222         222  2021-03-19 17:31:54+00:00
# 223         223  2021-03-19 17:26:18+00:00
# 224         224  2021-03-18 18:30:14+00:00
# 225         225  2021-03-17 19:57:33+00:00
#
#                                                 Tweets
# 0    Support new artist, help us grow!! Shill the S...
# 1    Support new artist, help us grow!! Shill the S...
# 2    Support new artist, help us grow!! Shill the S...
# 3    Support new artist, help us grow!! Shill the S...
# 4    Tech blog article by @arpaofficial cryptograph...
# ..                                                 ...
# ...
